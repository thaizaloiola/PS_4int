# %%
import pandas as pd

# %%
df= pd.read_csv('EXP_COMPLETA.csv', delimiter =';')

# %%
df
# Out:
#           CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0           1997      11  20079990       10      158        RJ       4
# 1           1997      11  48064000       10       63        SP       7
# 2           1997      11   2071300       10      351        SC       1
# 3           1997      11  19021100       10      586        MS       9
# 4           1997      11  90319090       10       40        ND       4
# ...          ...     ...       ...      ...      ...       ...     ...
# 23358755    2021       2  21039029       10      589        MG       1
# 23358756    2021       4  39079100       10      249        SP       1
# 23358757    2021       3   2031900       10      467        SP       1
# 23358758    2021       2  62114300       11      301        RJ       4
# 23358759    2021       4   7092000       10      434        SP       1
#
#            CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0          717700         0         200     540
# ...

# %%
import datetime as datetime

df_teste = pd.DataFrame({'yy' : list(df["CO_ANO"]),'mm':list(df['CO_MES'])})

df_teste['yy'].astype(int)
df_teste['mm'].astype(int)

df_teste['dd'] =""

n =[]

for i in df_teste['dd']:
    i = '01'
    n.append(i)

df_teste['dd'] = n

df_teste['dd'].astype(int)

df_teste2 = df_teste[["yy","mm","dd"]].copy()

df_teste2.columns = ["year", "month", "day"]
c = pd.to_datetime(df_teste2)
df_teste2['datas'] = c

df['anomes'] = df_teste2['datas'].values

df
# Out:
#           CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0           1997      11  20079990       10      158        RJ       4
# 1           1997      11  48064000       10       63        SP       7
# 2           1997      11   2071300       10      351        SC       1
# 3           1997      11  19021100       10      586        MS       9
# 4           1997      11  90319090       10       40        ND       4
# ...          ...     ...       ...      ...      ...       ...     ...
# 23358755    2021       2  21039029       10      589        MG       1
# 23358756    2021       4  39079100       10      249        SP       1
# 23358757    2021       3   2031900       10      467        SP       1
# 23358758    2021       2  62114300       11      301        RJ       4
# 23358759    2021       4   7092000       10      434        SP       1
#
#            CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB     anomes
# ...

# %%
n_by_month =pd.DataFrame(df.groupby(["anomes"])["VL_FOB"].sum()).reset_index()

# %%
#df['date'] = pd.to_datetime(df['date'])

n_by_month = n_by_month[~(n_by_month['anomes'] < '2010-01-01')]

# %%
n_by_month
# Out:
#         anomes       VL_FOB
# 156 2010-01-01  11153005703
# 157 2010-02-01  12066643269
# 158 2010-03-01  15637886925
# 159 2010-04-01  15074159639
# 160 2010-05-01  17632178264
# ..         ...          ...
# 287 2020-12-01  18451708927
# 288 2021-01-01  14936602807
# 289 2021-02-01  16351767724
# 290 2021-03-01  24347776483
# 291 2021-04-01  26480766246
#
# [136 rows x 2 columns]

# %%
dfimpo= pd.read_csv(r'C:\Users\thaiz\OneDrive\Documentos\PS4inteligence\IMP_COMPLETA\IMP_COMPLETA.csv', delimiter =';')

# %%
dfimpo
# Out:
#           CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0           1997       8  85369090       11      160        SP       1
# 1           1997      11  85164000       11      249        RS       4
# 2           1997       7  82159990       10      160        CE       1
# 3           1997       8  32041100       10       23        SP       4
# 4           1997       5  62104000       11      249        SP       4
# ...          ...     ...       ...      ...      ...       ...     ...
# 34884272    2021       1  90259090       10      160        RO       1
# 34884273    2021       1  59100000       10      161        PE       4
# 34884274    2021       4  39172900       10      455        PR       1
# 34884275    2021       1  84798999       11      355        SP       1
# 34884276    2021       3  73181600       10      607        BA       4
#
#            CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0          817800     55018         833    7384
# ...

# %%
df_teste2 = pd.DataFrame({'yy' : list(dfimpo["CO_ANO"]),'mm':list(dfimpo['CO_MES'])})

df_teste2['yy'].astype(int)
df_teste2['mm'].astype(int)

df_teste2['dd'] =""

n =[]

for i in df_teste2['dd']:
    i = '01'
    n.append(i)

df_teste2['dd'] = n

df_teste2['dd'].astype(int)

df_teste3 = df_teste2[["yy","mm","dd"]].copy()

df_teste3.columns = ["year", "month", "day"]
c = pd.to_datetime(df_teste3)
df_teste3['datas'] = c

dfimpo['anomes'] = df_teste3['datas'].values

dfimpo
# Out:
#           CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0           1997       8  85369090       11      160        SP       1
# 1           1997      11  85164000       11      249        RS       4
# 2           1997       7  82159990       10      160        CE       1
# 3           1997       8  32041100       10       23        SP       4
# 4           1997       5  62104000       11      249        SP       4
# ...          ...     ...       ...      ...      ...       ...     ...
# 34884272    2021       1  90259090       10      160        RO       1
# 34884273    2021       1  59100000       10      161        PE       4
# 34884274    2021       4  39172900       10      455        PR       1
# 34884275    2021       1  84798999       11      355        SP       1
# 34884276    2021       3  73181600       10      607        BA       4
#
#            CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB     anomes
# ...

# %%
n_by_monthimpo =pd.DataFrame(dfimpo.groupby(["anomes"])["VL_FOB"].sum()).reset_index()

# %%
n_by_monthimpo = n_by_monthimpo[~(n_by_monthimpo['anomes'] < '2010-01-01')]

# %%
n_by_monthimpo
# Out:
#         anomes       VL_FOB
# 156 2010-01-01  11628213109
# 157 2010-02-01  11936118599
# 158 2010-03-01  15181212723
# 159 2010-04-01  14007783168
# 160 2010-05-01  14374167768
# ..         ...          ...
# 287 2020-12-01  15748589294
# 288 2021-01-01  15351627871
# 289 2021-02-01  14533736111
# 290 2021-03-01  17861574696
# 291 2021-04-01  16131639156
#
# [136 rows x 2 columns]

# %%
n_by_monthimpo['VL_FOB'].astype(int)
# Out:
# 156   -1256688779
# 157    -948783289
# 158   -1998656461
# 159    1122881280
# 160    1489265880
#           ...
# 287   -1431279890
# 288   -1828241313
# 289    1648834223
# 290     681705512
# 291   -1048230028
# Name: VL_FOB, Length: 136, dtype: int32

# %%
n_by_month['VL_FOB'].astype(int)
# Out:
# 156   -1731896185
# 157    -818258619
# 158   -1541982259
# 159   -2105709545
# 160     452309080
#           ...
# 287    1271839743
# 288    2051700919
# 289    -828101460
# 290   -1422027293
# 291     710962470
# Name: VL_FOB, Length: 136, dtype: int32

# %%
balcomer = pd.DataFrame({'data' : list(n_by_month["anomes"]),'bc':list(n_by_month['VL_FOB'] - n_by_monthimpo['VL_FOB'])})

balcomer
# Out:
#           data           bc
# 0   2010-01-01   -475207406
# 1   2010-02-01    130524670
# 2   2010-03-01    456674202
# 3   2010-04-01   1066376471
# 4   2010-05-01   3258010496
# ..         ...          ...
# 131 2020-12-01   2703119633
# 132 2021-01-01   -415025064
# 133 2021-02-01   1818031613
# 134 2021-03-01   6486201787
# 135 2021-04-01  10349127090
#
# [136 rows x 2 columns]

# %%
x = n_by_monthimpo['anomes']
y = n_by_monthimpo['VL_FOB'] 
x1 =n_by_month['anomes']
y1 = n_by_month['VL_FOB']



plt.figure(figsize = (15,7.5))
plt.plot(x, y, label = 'importações')
plt.plot(x1, y1, label = 'exportações')

plt.legend(['importações', 'exportações'])

plt.grid()
plt.xlabel('Período')
plt.ylabel('US$ bilhões')
plt.title('Série histórica de exportações X importações brasileiras mensal')
plt.show()

# %%
x = balcomer['data']
y = balcomer['bc'] 

plt.figure(figsize = (15,7.5))
plt.plot(x, y)
plt.legend(['Balança comercial br'])
plt.grid()
plt.xlabel('Período')
plt.ylabel('US$ bilhões')
plt.title('Série histórica da balança comercial brasileiras mensal')
plt.show()
